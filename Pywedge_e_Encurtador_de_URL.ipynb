# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# # <font color='Green'>Dicas e Truques de Ciência de Dados</font>
#
# # <font color='Grey'> Pywedge - Configuração de Gráficos Interativos </font>

# %% [markdown]
# ![alt text](https://envylabs.com/wp-content/uploads/2020/04/blog-VisualizationMissteps-header1-smaller-1.gif)

# %% [markdown]
# https://pypi.org/project/pywedge/

# %% [markdown]
# https://pywedge-make-charts.herokuapp.com/

# %% [markdown]
# #Iniciando o **Pywedge_Charts**

# %% [markdown]
# Cria diferentes tipos de gráficos de visualização de Dados de forma interativa, ou seja, sem a necessidade de configurações adicionais:
#
# * Gráfico de dispersão
# * Gráfico de pizza
# * Bar Plot
# * Violino
# * Box Plot
# * Gráfico de Distribuição
# * Histograma
# * Gráfico de Correlação

# %% [markdown]
# ## O "Pywedge_Charts" precisa dos seguintes parâmetros:
#
#
# **1° Dataframe**
#
# **2° c** = Eliminar colunas redundantes (Id por exemplo)
#
# **3° y** = A variável Target (classe, etc)

# %% [markdown]
# ###Case 1

# %%
#Comando de Instalação
# !pip install pywedge

# %%
#Importação de Bibliotecas
import pywedge as pw

# %%
#importação da fonte de dados
import pandas as pd
train = pd.read_csv('/content/risco.csv')

# %%
train.head()

# %%
#Input de Parâmetros
mc = pw.Pywedge_Charts(train, c='id_cliente', y = 'Risco')

# %%
#Run
charts = mc.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="05b68ad0-5cc9-44fa-a093-f5306359233c" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("05b68ad0-5cc9-44fa-a093-f5306359233c")) {
#                     Plotly.newPlot(
#                         '05b68ad0-5cc9-44fa-a093-f5306359233c',
# ...

# %% [markdown]
# ### Case 2
# https://clck.ru/SjSGP

# %% [markdown]
# # Encurtador de URL para **Criação de Links**

# %% [markdown]
# ![alt text](https://www.bleepstatic.com/images/news/social-sites/twitter/twitter-url-abuse/tweet-abuse.gif)

# %% [markdown]
# ![alt text](https://help.grow.com/hc/article_attachments/360033126874/image-chart.gif)

# %%
#Instalação
# !pip install pyshorteners

# %%
#Importação
import pyshorteners

# %%
#Criação do link
link = 'https://mybinder.org/v2/gh/taknev83/pywedge_make_charts_heroku_demo/81ecbd94801f44d7fc05840cf884e82346a30f28?filepath=notebooks%2FPywedge_Make_Charts_Demo.ipynb'

# %%
#Run
print(pyshorteners.Shortener().clckru.short(link))
# Out:
# https://clck.ru/SjSGP

# %% [markdown]
# #Fim

# %% [markdown]
# ## Valeu!

# %% [markdown]
# ### #Links - Ciência dos Dados <a href="https://linktr.ee/cienciadosdados">https://linktr.ee/cienciadosdados</a>

# %% [markdown]
# ### #YouTube - Mais Aulas como essa no YouTube <a href="https://www.youtube.com/watch?v=IaIc5oHd3II&t=1569s">https://www.youtube.com/watch?v=IaIc5oHd3II&t=1569s</a>

# %%
from IPython.core.display import HTML
HTML('<iframe width="378" height="195" src="https://www.youtube.com/embed/LGlPzFyrk2g" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="378" height="195" src="https://www.youtube.com/embed/LGlPzFyrk2g" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
